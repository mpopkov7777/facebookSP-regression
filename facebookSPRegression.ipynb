# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from pylab import *
from scipy import stats 
# %matplotlib inline



df = pd.read_excel("/Users/markpopkov/Documents/spFbFiveYear.xls")

df.head()
# Out:
#          SP500   Facebook
# 0  1841.069946  53.709999
# 1  1848.359985  54.650002
# 2  1831.979980  54.709999
# 3  1831.369995  54.560001
# 4  1826.770020  57.200001

# %%
df.plot(kind='scatter', x='SP500', y='Facebook', figsize=(16,8))

# %%
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(df.SP500, df.Facebook)

# %%
print("r =", r_value) 
print("r sqr =", r_value ** 2)
# Out:
# r = 0.91614423363753
# r sqr = 0.839320256827297

# %%
print("p_value =", p_value)
print("std_error =", std_err)
# Out:
# p_value = 0.0
# std_error = 0.0014960239012980828
